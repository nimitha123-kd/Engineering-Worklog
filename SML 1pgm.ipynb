# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
prices = np.array([45, 50, 55, 60, 65, 70, 75, 90])
 
Q1 = np.percentile(prices, 25)
Q3 = np.percentile(prices, 75)
IQR = Q3 - Q1

print("House Prices:", prices)
print(f"25th Percentile (Q1): {Q1}")
print(f"75th Percentile (Q3): {Q3}")
print(f"Interquartile Range (IQR): {IQR}")
 
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")



outliers = prices[(prices < lower_bound) | (prices > upper_bound)]
print("Outliers:", outliers if len(outliers) > 0 else "None")

plt.boxplot(prices, vert=False, patch_artist=True)
plt.title('Boxplot of House Prices')
plt.xlabel('Price (Lakhs)')
plt.show()
# Out:
# House Prices: [45 50 55 60 65 70 75 90]
# 25th Percentile (Q1): 53.75
# 75th Percentile (Q3): 71.25
# Interquartile Range (IQR): 17.5
# Lower Bound: 27.5
# Upper Bound: 97.5
# Outliers: None
